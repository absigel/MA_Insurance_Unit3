# %% [markdown]
# # Compiling Massachusetts Insurance Data #

# %% [markdown]
# This notebook will teach how to compile a subset of data. Specifically, data regarding insurance in Massachusetts will be taken from data for County Health in the United States.
#
# ### Overview ###
#
# The main steps include:
#
# 1. Setting up
# 2. Filtering
# 3. Indexing
# 4. Defining
# 5. Exporting

# %% [markdown]
# ## Setting Up ##

# %% [markdown]
# First, pandas and numpy need to be imported with memorable abbreiviations. These packages allow us to use tools and functions in addition to those in Python. <b>Pandas</b> functions are useful for compiling data because they allow data to be stored with rows and columns, making it more easily comprehensible. Importing <b>Numpy</b> as well helps with some of the math functions. Both can be imported by using the following code.

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# It is important to define the DataFrame. We can use <b> df </b> to do so.
#
# Now, the data set needs to be uploaded. The County Health Dataset being used can be downloaded from Canvas. To upload the data set to the notebook, we can use `df=pd.read_csv()`.

# %%
df=pd.read_csv("CountyHealthData_2014-2015 (1).csv")

# %% [markdown]
# ## Filtering ##

# %% [markdown]
# In order to determine which row numbers represent the desired data, filtering can be used. By filtering out the State column for "MA", the numbers that correspond with Massachusetts data can be determined.
#
# We can use bracket notation `df["column"]` to do this. This utilizes two statements:
#
# 1. `df["State"]=="MA"` will search the State column for anything that equals `"MA"`.
#
# 2. `df[...]` will select the rows where this statement is true.

# %%
df[df["State"] == "MA"]
# Out:
#      State     Region     Division             County   FIPS  GEOID  \
# 2313    MA  Northeast  New England  Barnstable County  25001  25001
# 2314    MA  Northeast  New England  Barnstable County  25001  25001
# 2315    MA  Northeast  New England   Berkshire County  25003  25003
# 2316    MA  Northeast  New England   Berkshire County  25003  25003
# 2317    MA  Northeast  New England     Bristol County  25005  25005
# 2318    MA  Northeast  New England     Bristol County  25005  25005
# 2319    MA  Northeast  New England       Dukes County  25007  25007
# 2320    MA  Northeast  New England       Dukes County  25007  25007
# 2321    MA  Northeast  New England       Essex County  25009  25009
# 2322    MA  Northeast  New England       Essex County  25009  25009
# 2323    MA  Northeast  New England    Franklin County  25011  25011
# 2324    MA  Northeast  New England    Franklin County  25011  25011
# 2325    MA  Northeast  New England     Hampden County  25013  25013
# 2326    MA  Northeast  New England     Hampden County  25013  25013
# 2327    MA  Northeast  New England   Hampshire County  25015  25015
# 2328    MA  Northeast  New England   Hampshire County  25015  25015
# 2329    MA  Northeast  New England   Middlesex County  25017  25017
# 2330    MA  Northeast  New England   Middlesex County  25017  25017
# 2331    MA  Northeast  New England   Nantucket County  25019  25019
# 2332    MA  Northeast  New England   Nantucket County  25019  25019
# 2333    MA  Northeast  New England     Norfolk County  25021  25021
# 2334    MA  Northeast  New England     Norfolk County  25021  25021
# 2335    MA  Northeast  New England    Plymouth County  25023  25023
# 2336    MA  Northeast  New England    Plymouth County  25023  25023
# 2337    MA  Northeast  New England     Suffolk County  25025  25025
# 2338    MA  Northeast  New England     Suffolk County  25025  25025
# 2339    MA  Northeast  New England   Worcester County  25027  25027
# 2340    MA  Northeast  New England   Worcester County  25027  25027
# [28 rows x 64 columns]

# %% [markdown]
# ## Indexing ##

# %% [markdown]
# Using the row numbers that represent data from Massachusetts, the desired columns can be filtered out for those rows.
#
# This can be done through the use of the `.loc` attribute.
#
# In the outer brackets, the row numbers corresponding to the Massachusetts data need to be inserted. In the inner brackets, insert the names of the desired columns.

# %%
df.loc[2313:2340,["State","County", "Uninsured adults", "Uninsured children","Health care costs"]]
# Out:
#      State             County  Uninsured adults  Uninsured children  \
# 2313    MA  Barnstable County             0.070               0.023
# 2314    MA  Barnstable County             0.057               0.018
# 2315    MA   Berkshire County             0.057               0.020
# 2316    MA   Berkshire County             0.053               0.015
# 2317    MA     Bristol County             0.064               0.019
# 2318    MA     Bristol County             0.064               0.014
# 2319    MA       Dukes County             0.085               0.035
# 2320    MA       Dukes County             0.070               0.022
# 2321    MA       Essex County             0.067               0.021
# 2322    MA       Essex County             0.061               0.015
# 2323    MA    Franklin County             0.060               0.021
# 2324    MA    Franklin County             0.049               0.015
# 2325    MA     Hampden County             0.071               0.021
# 2326    MA     Hampden County             0.062               0.015
# 2327    MA   Hampshire County             0.055               0.019
# 2328    MA   Hampshire County             0.051               0.014
# 2329    MA   Middlesex County             0.054               0.017
# 2330    MA   Middlesex County             0.050               0.011
# 2331    MA   Nantucket County             0.092               0.036
# 2332    MA   Nantucket County             0.077               0.025
# 2333    MA     Norfolk County             0.039               0.013
# 2334    MA     Norfolk County             0.036               0.011
# 2335    MA    Plymouth County             0.053               0.018
# 2336    MA    Plymouth County             0.049               0.013
# 2337    MA     Suffolk County             0.076               0.022
# 2338    MA     Suffolk County             0.071               0.015
# 2339    MA   Worcester County             0.057               0.017
# 2340    MA   Worcester County             0.059               0.015
#
#       Health care costs
# 2313             9120.0
# 2314             8870.0
# 2315             9022.0
# 2316             8980.0
# 2317            10094.0
# 2318             9523.0
# 2319             9169.0
# 2320             8822.0
# 2321            10230.0
# 2322             9564.0
# 2323             7849.0
# 2324             7596.0
# 2325             9112.0
# 2326             8598.0
# 2327             8709.0
# 2328             8388.0
# 2329             9955.0
# 2330             9440.0
# 2331             8300.0
# 2332             8238.0
# 2333            10099.0
# 2334             9746.0
# 2335            10402.0
# 2336             9952.0
# 2337            10020.0
# 2338             9813.0
# 2339             9982.0
# 2340             9560.0

# %% [markdown]
# ## Defining ##

# %% [markdown]
# Next, the subset needs to be defined. This will allow us to export the data as a csv file in the next step.
#
# The subset will be named `MA_subset`. The desired name must be attached to the code for the data using an equal sign.

# %%
MA_insurance_subset = df.loc[2313:2340,["State","County", "Uninsured adults", "Uninsured children","Health care costs"]]

# %% [markdown]
# ## Exporting ##

# %% [markdown]
# Finally, the subset needs to be exported. This can be done using the `.to_csv()` method.
#
# Because the subset was previously named as `MA_insurance_subset`, the following code can be used.

# %%
MA_insurance_subset.to_csv("MA_insurance_subset.csv")

# %% [markdown]
# #### Now the subset is downloaded to the device as a csv file and the process is <b>complete</b>! ####
